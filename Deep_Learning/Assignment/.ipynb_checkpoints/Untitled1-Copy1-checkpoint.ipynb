# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
dataset = pd.read_csv('dataset_40_sonar.csv', header=None)

# %%
dataset
# Out:
#               0            1            2            3            4   \
# 0    attribute_1  attribute_2  attribute_3  attribute_4  attribute_5
# 1           0.02       0.0371       0.0428       0.0207       0.0954
# 2         0.0453       0.0523       0.0843       0.0689       0.1183
# 3         0.0262       0.0582       0.1099       0.1083       0.0974
# 4           0.01       0.0171       0.0623       0.0205       0.0205
# ..           ...          ...          ...          ...          ...
# 204       0.0187       0.0346       0.0168       0.0177       0.0393
# 205       0.0323       0.0101       0.0298       0.0564        0.076
# 206       0.0522       0.0437        0.018       0.0292       0.0351
# 207       0.0303       0.0353        0.049       0.0608       0.0167
# 208        0.026       0.0363       0.0136       0.0272       0.0214
#
#               5            6            7            8             9   ...  \
# 0    attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...
# 1         0.0986       0.1539       0.1601       0.3109        0.2111  ...
# 2         0.2583       0.2156       0.3481       0.3337        0.2872  ...
# 3          0.228       0.2431       0.3771       0.5598        0.6194  ...
# 4         0.0368       0.1098       0.1276       0.0598        0.1264  ...
# ..           ...          ...          ...          ...           ...  ...
# 204        0.163       0.2028       0.1694       0.2328        0.2684  ...
# 205       0.0958        0.099       0.1018        0.103        0.2154  ...
# 206       0.1171       0.1257       0.1178       0.1258        0.2529  ...
# 207       0.1354       0.1465       0.1123       0.1945        0.2354  ...
# 208       0.0338       0.0655         0.14       0.1843        0.2354  ...
#
#                51            52            53            54            55  \
# 0    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56
# 1          0.0027        0.0065        0.0159        0.0072        0.0167
# 2          0.0084        0.0089        0.0048        0.0094        0.0191
# 3          0.0232        0.0166        0.0095         0.018        0.0244
# 4          0.0121        0.0036         0.015        0.0085        0.0073
# ..            ...           ...           ...           ...           ...
# 204        0.0116        0.0098        0.0199        0.0033        0.0101
# 205        0.0061        0.0093        0.0135        0.0063        0.0063
# 206         0.016        0.0029        0.0051        0.0062        0.0089
# 207        0.0086        0.0046        0.0126        0.0036        0.0035
# 208        0.0146        0.0129        0.0047        0.0039        0.0061
#
#                56            57            58            59     60
# 0    attribute_57  attribute_58  attribute_59  attribute_60  Class
# 1           0.018        0.0084         0.009        0.0032   Rock
# 2           0.014        0.0049        0.0052        0.0044   Rock
# 3          0.0316        0.0164        0.0095        0.0078   Rock
# 4           0.005        0.0044         0.004        0.0117   Rock
# ..            ...           ...           ...           ...    ...
# 204        0.0065        0.0115        0.0193        0.0157   Mine
# 205        0.0034        0.0032        0.0062        0.0067   Mine
# 206         0.014        0.0138        0.0077        0.0031   Mine
# 207        0.0034        0.0079        0.0036        0.0048   Mine
# 208         0.004        0.0036        0.0061        0.0115   Mine
#
# [209 rows x 61 columns]

# %%
dataset=dataset.drop(dataset.index[[0]])

# %%
dataset
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 1      0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 2    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 3    0.0262  0.0582  0.1099  0.1083  0.0974   0.228  0.2431  0.3771  0.5598
# 4      0.01  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 5    0.0762  0.0666  0.0481  0.0394   0.059  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 204  0.0187  0.0346  0.0168  0.0177  0.0393   0.163  0.2028  0.1694  0.2328
# 205  0.0323  0.0101  0.0298  0.0564   0.076  0.0958   0.099  0.1018   0.103
# 206  0.0522  0.0437   0.018  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 207  0.0303  0.0353   0.049  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 208   0.026  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655    0.14  0.1843
#
#          9   ...      51      52      53      54      55      56      57  \
# 1    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167   0.018  0.0084
# 2    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191   0.014  0.0049
# 3    0.6194  ...  0.0232  0.0166  0.0095   0.018  0.0244  0.0316  0.0164
# 4    0.1264  ...  0.0121  0.0036   0.015  0.0085  0.0073   0.005  0.0044
# 5    0.4459  ...  0.0031  0.0054  0.0105   0.011  0.0015  0.0072  0.0048
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 204  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 205  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 206  0.2529  ...   0.016  0.0029  0.0051  0.0062  0.0089   0.014  0.0138
# 207  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 208  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061   0.004  0.0036
#
#          58      59    60
# 1     0.009  0.0032  Rock
# 2    0.0052  0.0044  Rock
# 3    0.0095  0.0078  Rock
# 4     0.004  0.0117  Rock
# 5    0.0107  0.0094  Rock
# ..      ...     ...   ...
# 204  0.0193  0.0157  Mine
# 205  0.0062  0.0067  Mine
# 206  0.0077  0.0031  Mine
# 207  0.0036  0.0048  Mine
# 208  0.0061  0.0115  Mine
#
# [208 rows x 61 columns]

# %%
properties = list(dataset.columns.values)
#properties.remove(dataset.)
#print(properties)
X = dataset.drop(columns=60, axis=1)
y = dataset[60]

# %%
print(y)
# Out:
# 1      Rock
# 2      Rock
# 3      Rock
# 4      Rock
# 5      Rock
#        ...
# 204    Mine
# 205    Mine
# 206    Mine
# 207    Mine
# 208    Mine
# Name: 60, Length: 208, dtype: object

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy
# load pima indians dataset
X = dataset.drop(columns=60, axis=1)
Y = dataset[60]

# create model
model = Sequential()
model.add(Dense(12, input_dim=60, activation='relu'))
model.add(Dense(60, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit the model
history = model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, verbose=0)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Input In [41], in <cell line: 18>()
#      16 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#      17 # Fit the model
# ---> 18 history = model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, verbose=0)
#      19 # list all data in history
#      20 print(history.history.keys())
#
# File ~\anaconda3\envs\dl\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\envs\dl\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# UnimplementedError: Graph execution error:
#
# Detected at node 'sequential_20/Cast' defined at (most recent call last):
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 2854, in run_cell
#       result = self._run_cell(
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 2900, in _run_cell
#       return runner(coro)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3301, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\IPython\core\interactiveshell.py", line 3361, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\icyro\AppData\Local\Temp\ipykernel_21844\2009814712.py", line 18, in <cell line: 18>
#       history = model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, verbose=0)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\training.py", line 1384, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\training.py", line 1021, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\training.py", line 1010, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\training.py", line 1000, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\training.py", line 859, in train_step
#       y_pred = self(x, training=True)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\sequential.py", line 374, in call
#       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\functional.py", line 451, in call
#       return self._run_internal_graph(
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\functional.py", line 571, in _run_internal_graph
#       y = self._conform_to_reference_input(y, ref_input=x)
#     File "C:\Users\icyro\anaconda3\envs\dl\lib\site-packages\keras\engine\functional.py", line 671, in _conform_to_reference_input
#       tensor = tf.cast(tensor, dtype=ref_input.dtype)
# Node: 'sequential_20/Cast'
# Cast string to float is not supported
# 	 [[{{node sequential_20/Cast}}]] [Op:__inference_train_function_7446]

# %%
dataset.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
#        ...
# 56    object
# 57    object
# 58    object
# 59    object
# 60    object
# Length: 61, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 1 to 208
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    object
#  1   1       208 non-null    object
#  2   2       208 non-null    object
#  3   3       208 non-null    object
#  4   4       208 non-null    object
#  5   5       208 non-null    object
#  6   6       208 non-null    object
#  7   7       208 non-null    object
#  8   8       208 non-null    object
#  9   9       208 non-null    object
#  10  10      208 non-null    object
#  11  11      208 non-null    object
#  12  12      208 non-null    object
#  13  13      208 non-null    object
#  14  14      208 non-null    object
#  15  15      208 non-null    object
#  16  16      208 non-null    object
#  17  17      208 non-null    object
#  18  18      208 non-null    object
#  19  19      208 non-null    object
#  20  20      208 non-null    object
#  21  21      208 non-null    object
#  22  22      208 non-null    object
#  23  23      208 non-null    object
#  24  24      208 non-null    object
#  25  25      208 non-null    object
#  26  26      208 non-null    object
#  27  27      208 non-null    object
#  28  28      208 non-null    object
#  29  29      208 non-null    object
#  30  30      208 non-null    object
#  31  31      208 non-null    object
#  32  32      208 non-null    object
#  33  33      208 non-null    object
#  34  34      208 non-null    object
#  35  35      208 non-null    object
#  36  36      208 non-null    object
#  37  37      208 non-null    object
#  38  38      208 non-null    object
#  39  39      208 non-null    object
#  40  40      208 non-null    object
#  41  41      208 non-null    object
#  42  42      208 non-null    object
#  43  43      208 non-null    object
#  44  44      208 non-null    object
#  45  45      208 non-null    object
#  46  46      208 non-null    object
#  47  47      208 non-null    object
#  48  48      208 non-null    object
#  49  49      208 non-null    object
#  50  50      208 non-null    object
#  51  51      208 non-null    object
#  52  52      208 non-null    object
#  53  53      208 non-null    object
#  54  54      208 non-null    object
#  55  55      208 non-null    object
#  56  56      208 non-null    object
#  57  57      208 non-null    object
#  58  58      208 non-null    object
#  59  59      208 non-null    object
#  60  60      208 non-null    object
# dtypes: object(61)
# memory usage: 99.3+ KB
